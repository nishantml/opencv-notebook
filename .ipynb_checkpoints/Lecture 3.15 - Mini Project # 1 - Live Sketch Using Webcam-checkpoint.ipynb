# %% [markdown]
# ## Live Sketch Using Webcam

# %%
import cv2
import numpy as np

# Our sketch generating function
def sketch(image):
    # Convert image to grayscale
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Clean up image using Guassian Blur
    img_gray_blur = cv2.GaussianBlur(img_gray, (5,5), 0)
    
    # Extract edges
    canny_edges = cv2.Canny(img_gray_blur, 10, 70)
    
    # Do an invert binarize the image 
    ret, mask = cv2.threshold(canny_edges, 70, 255, cv2.THRESH_BINARY_INV)
    return mask


# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow('Our Live Sketcher', sketch(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Our sketch generating function
def grayscale(image):
    # Convert image to grayscale
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    return img_gray


# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow('Our Live grayscale image', grayscale(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# useful color space is HSV generating function
def HSVfiltering(image):
    # Convert image to HSV
    #Infact HSV is very useful in color filtering.
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # try to uncomment one of them onece and run the code
    hsv_final = hsv_image #HSV image
    
#     hsv_final = hsv_image[:, :, 0] #Hue channel
    
#     hsv_final = hsv_image[:, :, 1] #Saturation channel
    
#     hsv_final = hsv_image[:, :, 2] #Value channel

    return hsv_final


# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow('Our Live HSV filtering', HSVfiltering(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Our explore lookng at individual channels in an RGB image generating function
def RGBimage(image,outputType=''):
    B, G, R = cv2.split(image)
    
    if outputType == 'B':
        return B
    
    if outputType == 'G':
        return G
    
    if outputType == 'R':
        return R
    
    if outputType == 'bluecolor':
#         amplify the blue color
        merged = cv2.merge([B+100, G, R])
        return merged
    
    if outputType == '':
#       re-make the original image
        merged = cv2.merge([B, G, R]) 
        return merged


# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow('Our Live RGB image', RGBimage(frame,'bluecolor'))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()
